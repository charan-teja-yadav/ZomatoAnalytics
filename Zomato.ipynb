# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# Loading the Dataset

# %%
df = pd.read_csv('Zomato data .csv')

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# Handling the Rate

# %%
def handleRate(value):
    value = str(value).split('/')
    value = value[0]
    return float(value)

# %%
df['rate'] = df['rate'].apply(handleRate)

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df[df['rate']< 3]
# Out:
#                                          name online_order book_table  rate  \
# 31                                 Foodiction          Yes         No   2.8
# 36                             Fast And Fresh          Yes         No   2.8
# 73                                   LSD Cafe           No         No   2.9
# 94                            Nandhini Deluxe           No         No   2.6
# 124  Kwality Wall's Swirl's Happiness Station           No         No   2.9
# 125                      Soms Kitchen & Bakes           No         No   2.9
# 126                   Banashankari Nati Style           No         No   2.9
# 137                      Hotel Andhra Speices           No         No   2.9
# 138              Sri Murari Family Restaurant           No         No   2.9
# 139                    Aramane Donne Biriyani           No         No   2.9
#
#      votes  approx_cost(for two people) listed_in(type)
# 31     506                          500           other
# ...

# %% [markdown]
# Types of restaurant

# %%
sns.countplot(x = df['listed_in(type)'],palette=['red', 'green', 'blue','yellow'])
warnings.filterwarnings('ignore')

plt.xlabel('types of restaurant')
plt.show()

# %% [markdown]
# Majority restaurants fall in Dining

# %%
grouped = df.groupby('listed_in(type)')['votes'].sum()

# %%
result = pd.DataFrame({'votes':grouped})
plt.plot(result,c = 'green',marker = "o")
X=plt.xlabel('listed_in(type)',c = 'red',size = 20)
Y=plt.ylabel('votes',c = 'red',size = 20)
plt.title("Count of votes of restaurant type")
# Out:
# Text(0.5, 1.0, 'Count of votes of restaurant type')

# %%
plt.hist(df['rate'],bins=5)
plt.title('Majority of rating restaurants receive')
plt.show()

# %% [markdown]
# Majority of the ratings received are between 3.5 and 4.0

# %% [raw]
# Average order spending by couples

# %%
couple_data = df['approx_cost(for two people)']

sns.countplot(x = couple_data)
plt.title('Average spending on Orders')
# Out:
# Text(0.5, 1.0, 'Average spending on Orders')

# %%
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes   4.1    775
# 1           Spice Elephant          Yes         No   4.1    787
# 2          San Churro Cafe          Yes         No   3.8    918
# 3    Addhuri Udupi Bhojana           No         No   3.7     88
# 4            Grand Village           No         No   3.8    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No   3.3      0
# 144        New Indraprasta           No         No   3.3      0
# 145           Anna Kuteera          Yes         No   4.0    771
# 146                 Darbar           No         No   3.0     98
# 147          Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# Which mode receives maximum rating

# %%
plt.figure(figsize = (6,6))
sns.boxplot(x = 'online_order',y = 'rate',data = df,palette='Set1')
plt.show()

# %% [markdown]
# Conclusion: Offline order received lower rating compared to online order

# %%
pivot_table = df.pivot_table(index = 'listed_in(type)',columns = 'online_order',aggfunc = 'size',fill_value=0)
sns.heatmap(pivot_table,annot = True,cmap = 'YlGnBu',fmt = 'd')
plt.title('Heatmap')
plt.xlabel('online_order')
plt.ylabel('listed_in(type)')
plt.show()

# %% [markdown]
# Conclusion: As per the heatmap, Dining restaurants received more offline orders,From this we understood that people prefer to order snacks online from cafes where they are intrested to come in person for the restaurants
